# %% [markdown]
# Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import scipy.stats as st
# %matplotlib inline

# %% [markdown]
# Задаём n и  p для биномиального распределения , n1,n2,n3

# %%
n=100
n1=5
n2=10
n3=50
p=0.4
b1 = st.binom(n, p)
b1.rvs(1000)
# Out:
# array([37, 36, 46, 39, 52, 38, 38, 52, 45, 33, 37, 49, 37, 43, 26, 30, 34,
#        38, 38, 34, 32, 48, 36, 36, 48, 38, 46, 42, 45, 41, 38, 49, 43, 46,
#        54, 44, 46, 45, 35, 38, 42, 31, 29, 32, 40, 35, 44, 36, 43, 43, 31,
#        37, 37, 35, 33, 38, 42, 37, 37, 44, 36, 37, 43, 46, 47, 39, 39, 42,
#        44, 40, 37, 40, 37, 44, 33, 37, 37, 46, 44, 42, 36, 44, 43, 48, 40,
#        44, 37, 43, 44, 36, 46, 38, 42, 38, 42, 44, 45, 42, 37, 45, 44, 44,
#        45, 35, 40, 40, 40, 31, 42, 35, 39, 35, 54, 36, 42, 41, 41, 41, 42,
#        42, 52, 52, 36, 42, 49, 39, 43, 45, 38, 42, 37, 41, 39, 35, 40, 34,
#        41, 39, 24, 46, 44, 38, 38, 44, 36, 34, 41, 32, 38, 35, 41, 44, 34,
#        40, 41, 41, 33, 40, 34, 38, 46, 46, 42, 46, 39, 39, 50, 42, 41, 40,
#        40, 35, 39, 38, 41, 35, 47, 37, 42, 33, 34, 41, 34, 43, 34, 44, 37,
#        31, 40, 42, 38, 42, 34, 40, 37, 43, 28, 50, 35, 45, 44, 32, 43, 35,
#        39, 41, 35, 41, 36, 35, 31, 46, 36, 40, 37, 48, 40, 40, 44, 43, 41,
#        43, 43, 31, 41, 44, 40, 39, 37, 42, 43, 48, 31, 45, 32, 38, 33, 40,
#        44, 42, 42, 42, 43, 32, 38, 35, 33, 47, 42, 31, 42, 34, 37, 48, 39,
#        32, 40, 37, 42, 47, 49, 38, 43, 35, 43, 42, 46, 39, 27, 32, 42, 41,
#        40, 38, 42, 43, 38, 36, 36, 41, 42, 46, 30, 35, 35, 46, 38, 40, 42,
#        38, 37, 45, 42, 35, 47, 43, 42, 34, 39, 42, 42, 32, 40, 35, 39, 41,
#        36, 38, 30, 34, 41, 36, 40, 37, 36, 41, 44, 41, 39, 38, 45, 45, 43,
#        42, 41, 40, 43, 42, 33, 38, 41, 47, 38, 41, 47, 37, 34, 41, 34, 34,
#        37, 35, 39, 41, 49, 55, 50, 47, 39, 36, 42, 37, 41, 40, 44, 40, 40,
#        40, 42, 30, 33, 33, 37, 41, 33, 37, 31, 44, 49, 40, 37, 40, 41, 42,
#        44, 33, 31, 39, 36, 43, 36, 37, 35, 38, 38, 45, 36, 31, 37, 43, 43,
#        35, 41, 43, 45, 45, 46, 31, 38, 41, 38, 43, 46, 40, 40, 48, 44, 39,
#        35, 39, 36, 41, 31, 40, 51, 37, 35, 39, 39, 40, 47, 39, 33, 42, 36,
#        41, 31, 39, 41, 43, 42, 45, 28, 40, 36, 35, 46, 37, 37, 37, 42, 39,
#        43, 37, 39, 46, 46, 31, 46, 33, 36, 37, 32, 38, 43, 43, 46, 45, 35,
#        32, 33, 40, 41, 47, 39, 35, 44, 41, 40, 36, 31, 48, 34, 39, 40, 33,
#        43, 31, 41, 46, 38, 39, 40, 36, 29, 46, 29, 34, 29, 41, 43, 46, 44,
#        39, 35, 28, 50, 39, 40, 45, 39, 39, 36, 34, 44, 37, 43, 46, 42, 42,
#        45, 40, 40, 40, 35, 50, 50, 46, 34, 36, 48, 35, 36, 41, 40, 33, 49,
#        31, 39, 40, 30, 38, 36, 35, 41, 47, 48, 45, 49, 35, 43, 35, 37, 36,
#        46, 43, 36, 54, 42, 36, 53, 37, 52, 34, 41, 44, 48, 41, 43, 37, 42,
#        46, 42, 41, 43, 41, 38, 37, 51, 46, 43, 41, 41, 34, 42, 42, 40, 40,
#        44, 40, 43, 42, 46, 40, 44, 39, 36, 42, 44, 46, 39, 30, 39, 45, 34,
#        44, 48, 38, 36, 48, 45, 44, 35, 37, 34, 44, 43, 42, 37, 35, 40, 43,
#        42, 35, 40, 35, 47, 39, 44, 44, 43, 34, 40, 38, 38, 33, 35, 45, 33,
#        44, 32, 48, 39, 36, 42, 52, 36, 46, 48, 38, 40, 34, 37, 34, 44, 38,
#        32, 36, 37, 40, 44, 41, 38, 44, 31, 36, 34, 40, 43, 33, 45, 50, 34,
#        39, 35, 40, 38, 37, 40, 44, 49, 39, 40, 41, 45, 40, 48, 35, 47, 42,
#        45, 35, 41, 47, 40, 39, 41, 36, 46, 37, 39, 46, 38, 38, 43, 32, 45,
#        38, 47, 45, 39, 41, 34, 42, 37, 37, 41, 41, 46, 48, 41, 36, 48, 44,
#        36, 41, 31, 33, 40, 40, 36, 41, 34, 41, 42, 39, 31, 35, 38, 41, 42,
#        45, 37, 39, 34, 51, 44, 42, 42, 41, 44, 43, 33, 32, 40, 39, 41, 39,
#        38, 48, 40, 43, 49, 49, 39, 42, 41, 42, 40, 34, 44, 42, 39, 43, 49,
#        36, 35, 37, 46, 44, 29, 43, 36, 42, 37, 37, 39, 53, 32, 40, 37, 36,
#        44, 45, 44, 43, 32, 44, 47, 42, 32, 43, 51, 41, 31, 44, 34, 40, 40,
#        37, 38, 38, 40, 43, 45, 40, 45, 41, 41, 36, 34, 42, 33, 37, 45, 43,
#        39, 28, 25, 42, 49, 34, 31, 36, 41, 34, 33, 36, 40, 45, 35, 44, 50,
#        47, 46, 44, 44, 40, 42, 41, 42, 40, 36, 41, 43, 42, 37, 37, 40, 46,
#        41, 38, 30, 40, 49, 44, 37, 42, 51, 48, 45, 34, 41, 42, 39, 38, 40,
#        45, 42, 40, 36, 34, 43, 30, 42, 40, 34, 45, 35, 34, 44, 44, 36, 31,
#        41, 40, 44, 46, 38, 30, 41, 40, 45, 41, 46, 38, 42, 31, 39, 39, 29,
#        38, 39, 42, 42, 40, 35, 36, 32, 39, 39, 39, 42, 41, 39, 42, 42, 44,
#        27, 40, 38, 54, 43, 40, 39, 34, 30, 46, 38, 45, 44, 41, 36, 46, 43,
#        47, 45, 41, 44, 41, 32, 48, 36, 39, 29, 40, 42, 35, 40, 35, 40, 34,
#        31, 45, 42, 42, 47, 45, 44, 44, 45, 42, 43, 39, 39, 34, 38, 39, 35,
#        34, 42, 41, 42, 40, 44, 29, 46, 44, 46, 37, 38, 28, 35, 48, 44, 32,
#        33, 44, 41, 34, 49, 35, 32, 44, 41, 36, 42, 42, 33, 41])

# %%
x = np.linspace(0,50,10)
cdf = b1.cdf(x)
plt.step(x, cdf)

plt.ylabel('$y$')
plt.xlabel('$x$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8d50a2ccec19> in <module>()
#       1 x = np.linspace(0,50,10)
#       2 cdf = b1.cdf(x)
# ----> 3 plt.step(x, cdf)
#       4
#       5 plt.ylabel('$y$')
#
# NameError: name 'plt' is not defined

# %%
x = np.linspace(-50,50,1000)
cdf = b1.cdf(x)
plt.plot(x, cdf, label='theor', alpha=10)
plt.legend()
plt.ylabel('$y2$')
plt.xlabel('$x$')

# %%
s1 = b1.rvs(n1)
s2 = b1.rvs(n2)
s3 = b1.rvs(n3)
norm1= st.norm(n1*p, n1*p*(1-p) )
norm2= st.norm(n2*p, n2*p*(1-p) )
norm3= st.norm(n3*p, n3*p*(1-p) )

# %% [markdown]
# Случай n=5

# %%
plt.hist(s1, bins=1000, normed=True)
plt.ylabel(' 10 samples')
plt.xlabel('$x$')

x = np.linspace(-50,50,10)
pdf = norm1.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$y1')
plt.xlabel('$x$')

# %% [markdown]
# Случай n=10

# %%
plt.hist(s2, bins=1000, normed=True)
plt.ylabel(' 10 samples')
plt.xlabel('$x$')

x = np.linspace(-50,50,10)
pdf = norm2.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$y2')
plt.xlabel('$x$')

# %% [markdown]
# Случай n=50

# %%
plt.hist(s3, bins=1000, normed=True)
plt.ylabel(' 50 samples')
plt.xlabel('$x$')

x = np.linspace(-50,50,10)
pdf = norm3.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$y2')
plt.xlabel('$x$')

# %% [markdown]
# Вывод: более высокий порядок объёма выборки более качественно характеризует распределение
